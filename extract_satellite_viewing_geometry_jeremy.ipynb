# %%
import os
import glob
import math
import numpy as np
import matplotlib.pyplot as plt
import rasterio
from rasterio.plot import show_hist
from scipy.spatial import distance

# %% [markdown]
# # Outputting raw RGB Image Metadata

# %%
# Define file path
RGB_folder = "Track3-RGB-1"
RGB_filename = "JAX_068_001_RGB.tif"
rgb_image_path = os.path.join(RGB_folder, RGB_filename)

# Open the RGB image file
rgb_image = rasterio.open(rgb_image_path)

# Print comprehensive metadata for the RGB image
print("\nComprehensive RGB Image Metadata:")
print("=" * 50)
print("Tags:")
for tag, value in rgb_image.tags().items():
    print(f"  {tag}: {value}")

print("\nProfile:")
for key, value in rgb_image.profile.items():
    print(f"  {key}: {value}")

# Check for EXIF data (may contain camera information)
print("\nEXIF data (if available):")
try:
    for tag, value in rgb_image.tags(ns='EXIF').items():
        print(f"  {tag}: {value}")
except Exception as e:
    print(f"  No EXIF data available: {e}")

# Check for geospatial transformation information (which could be related to camera pose)
print("\nGeospatial Transform Information:")
print(f"  Transform: {rgb_image.transform}")
print(f"  CRS: {rgb_image.crs}")

# Check if there are any RPCs (Rational Polynomial Coefficients) 
# These are often used for satellite imagery positioning
print("\nRPC Information (if available):")
try:
    rpc = rgb_image.rpcs
    if rpc:
        print(f"  RPC: {rpc.__dict__}")
    else:
        print("  No RPC data available")
except Exception as e:
    print(f"  Error retrieving RPC data: {e}")

# Check for any WorldView-3 specific metadata 
# (often satellite vendors include metadata in specific namespaces)
print("\nVendor-Specific Metadata:")
namespaces = rgb_image.tag_namespaces()
print(f"  Available tag namespaces: {namespaces}")

for ns in namespaces:
    if ns != 'IMAGE_STRUCTURE' and ns != '':  # Skip common namespace
        try:
            print(f"\n  Namespace: {ns}")
            for tag, value in rgb_image.tags(ns=ns).items():
                print(f"    {tag}: {value}")
        except Exception as e:
            print(f"    Error reading namespace {ns}: {e}")

# Try to find camera orientation/position information in any available metadata
print("\nLooking for camera pose information...")
# List of common terms that might indicate camera pose information
pose_terms = ['orientation', 'pose', 'position', 'exterior', 'extrinsic', 
              'camera', 'view', 'angle', 'azimuth', 'elevation', 'satellite',
              'sensor', 'look', 'incidence', 'off-nadir']

metadata_found = False
for ns in namespaces:
    try:
        tags = rgb_image.tags(ns=ns)
        for tag, value in tags.items():
            if any(term in tag.lower() for term in pose_terms):
                print(f"  Possible camera pose info - {ns}:{tag}: {value}")
                metadata_found = True
    except Exception:
        pass

if not metadata_found:
    print("  No obvious camera pose information found in the metadata.")
    print("  You may need to check for additional files (RPC files, metadata XML) that came with the dataset.")
# Out:
# Comprehensive RGB Image Metadata:
# ==================================================
# Tags:
#   NITF_ABPP: 11
#   NITF_CCS_COLUMN: 0
#   NITF_CCS_ROW: 0
#   NITF_CLEVEL: 06
#   NITF_ENCRYP: 0
#   NITF_FBKGC: 126,126,126
#   NITF_FDT: 20170123145345
#   NITF_FHDR: NITF02.10
#   NITF_FSCLAS: U
#   NITF_FSCLSY: US
#   NITF_FSCOP: 00000
#   NITF_FSCPYS: 00000
#   NITF_FSCTLH: 1
#   NITF_FTITLE: 05OCT14WV031100014OCT05160138-M1BS-500648062040_01_P001         GA E0AAAAAAKAAJ0
#   NITF_IALVL: 0
#   NITF_IC: C8
#   NITF_ICAT: MS
#   NITF_ICORDS: G
#   NITF_IDATIM: 20141005160138
#   NITF_IDLVL: 1
#   NITF_IGEOLO: 301359N0814231W302157N0814208W302159N0813414W301356N0813436W
#   NITF_IID1: M10209A800
#   NITF_IID2: 05OCT14WV031100014OCT05160138-M1BS-500648062040_01_P001         GA E0AAAAAAKAAJ0
#   NITF_ILOC_COLUMN: 0
#   NITF_ILOC_ROW: 0
#   NITF_IMAG: 1.0
#   NITF_IMAGE_COMMENTS: The imagery and metadata data on this media is the property of                  DigitalGlobe and is licensed for use only. All use must be in                   accordance with the terms of the license that accompanies the media.            If the license is purchased under contract NMA 301 99 D003, use is              in accordance with the license therein
#   NITF_IMODE: B
#   NITF_IREP: MULTI
#   NITF_ISCLAS: U
#   NITF_ISCLSY: US
#   NITF_ISCTLH: 1
#   NITF_ISORCE: DigitalGlobe
#   NITF_OSTAID: NDL-W
#   NITF_PJUST: R
#   NITF_PVTYPE: INT
#   NITF_STYPE: BF01
#   AREA_OR_POINT: Area
#
# Profile:
#   driver: GTiff
#   dtype: uint8
#   nodata: None
#   width: 2048
#   height: 2048
#   count: 3
#   crs: None
#   transform: | 1.00, 0.00, 0.00|
# | 0.00, 1.00, 0.00|
# | 0.00, 0.00, 1.00|
#   blockxsize: 2048
#   blockysize: 1
#   tiled: False
#   compress: deflate
#   interleave: pixel
#
# EXIF data (if available):
#
# Geospatial Transform Information:
#   Transform: | 1.00, 0.00, 0.00|
# | 0.00, 1.00, 0.00|
# | 0.00, 0.00, 1.00|
#   CRS: None
#
# RPC Information (if available):
#   Error retrieving RPC data: 'RPC' object has no attribute '__dict__'
#
# Vendor-Specific Metadata:
#   Available tag namespaces: ['IMAGE_STRUCTURE', 'RPC', 'DERIVED_SUBDATASETS']
#
#   Namespace: RPC
#     ERR_BIAS: -1
#     ERR_RAND: -1
#     HEIGHT_OFF: -21
#     HEIGHT_SCALE: 501
#     LAT_OFF: 30.2992
#     LAT_SCALE: 0.0686
#     LINE_DEN_COEFF: 1 0.0008312957 -0.001082452 -0.0003568737 -7.909193e-05 -4.39406e-06 -2.115065e-06 0.0002097118 -5.697575e-05 -8.781703e-05 1.256313e-06 0.0006978909 2.804975e-06 9.852023e-08 -8.403722e-05 1.106864e-07 1.76161e-07 -1.72154e-05 2.846286e-08 5.846147e-08
#     LINE_NUM_COEFF: -0.001819798 1.05893 -0.04865194 -0.008931413 0.0009396401 0.0003210434 -2.958493e-05 0.0009050124 2.154841e-06 -1.973179e-06 -2.197979e-06 -0.0003278231 -7.328548e-05 -9.277953e-05 9.503792e-05 3.25173e-06 4.273859e-06 2.187546e-06 6.594836e-07 7.837837e-07
#     LINE_OFF: 8765.44607510303
#     LINE_SCALE: 19234
#     LONG_OFF: -81.6397
#     LONG_SCALE: 0.0698
#     SAMP_DEN_COEFF: 1 0.003334898 0.00109964 -0.0004772925 -5.910318e-05 2.812519e-06 -2.379091e-06 4.279629e-05 -9.70496e-07 -1.117039e-05 -1.463578e-07 -4.370834e-06 -1.299386e-06 -6.066658e-08 3.634214e-06 4.180732e-08 4.706415e-08 4.165668e-07 0 0
#     SAMP_NUM_COEFF: -0.006759414 0.00105125 1.031473 -0.02411341 -0.003243495 -0.0007650443 0.0003055273 -0.0001333309 0.005703244 -2.706692e-07 -1.214205e-05 -0.0003291101 3.334586e-05 -8.330706e-07 -5.623914e-05 9.574234e-06 -1.11744e-05 1.311167e-05 3.085137e-06 2.746404e-07
#     SAMP_OFF: -14760.5830308314
#     SAMP_SCALE: 21250
#
#   Namespace: DERIVED_SUBDATASETS
#     DERIVED_SUBDATASET_1_NAME: DERIVED_SUBDATASET:LOGAMPLITUDE:Track3-RGB-1\JAX_068_001_RGB.tif
#     DERIVED_SUBDATASET_1_DESC: log10 of amplitude of input bands from Track3-RGB-1\JAX_068_001_RGB.tif
#
# Looking for camera pose information...
#   No obvious camera pose information found in the metadata.
#   You may need to check for additional files (RPC files, metadata XML) that came with the dataset.

# %% [markdown]
# # Displaying one view of the scene next to the DSM ground truth

# %%
# Define file paths
dsm_path = "Track3-Truth/JAX_068_DSM.tif"
RGB_folder = "Track3-RGB-1"
RGB_filename = "JAX_068_001_RGB.tif"
rgb_image_path = os.path.join(RGB_folder, RGB_filename)

# Open the RGB image file
rgb_image = rasterio.open(rgb_image_path)

# Open the DSM file
dsm_dataset = rasterio.open(dsm_path)

# Print basic information about DSM
print("DSM File info:")
print(f"Width: {dsm_dataset.width} pixels")
print(f"Height: {dsm_dataset.height} pixels")
print(f"Number of bands: {dsm_dataset.count}")
print(f"Data type: {dsm_dataset.dtypes[0]}")
print(f"Coordinate reference system: {dsm_dataset.crs}")
print(f"Transform:\n{dsm_dataset.transform}")

# Read the DSM data
dsm_data = dsm_dataset.read(1)  # Read first band

# Print DSM statistics
print("\nDSM Data statistics:")
print(f"Min value: {dsm_data.min()}")
print(f"Max value: {dsm_data.max()}")
print(f"Mean value: {dsm_data.mean()}")

# Open the rgb image
rgb_image = rasterio.open(rgb_image_path)

# Print basic information about rgb image
print("\nRGB satellite image info:")
print(f"Width: {rgb_image.width} pixels")
print(f"Height: {rgb_image.height} pixels")
print(f"Number of bands: {rgb_image.count}")
print(f"Data type: {rgb_image.dtypes[0]}")

# Display RGB image and DSM side by side
red = rgb_image.read(1)
green = rgb_image.read(2)
blue = rgb_image.read(3)

# Stack bands and prepare for display
rgb_display = np.stack((red, green, blue), axis=2)
rgb_display = np.clip(rgb_display, 0, 255).astype(np.uint8)

# Read DSM data
dsm_data = dsm_dataset = rasterio.open(dsm_path).read(1)

# Create the visualization
fig, axs = plt.subplots(1, 2, figsize=(20, 8))

# Display RGB image
axs[0].imshow(rgb_display)
axs[0].set_title('RGB satellite image')
axs[0].axis('off')

# Display DSM
dsm_plot = axs[1].imshow(dsm_data, cmap='terrain')
axs[1].set_title('DSM (Ground Truth)')
axs[1].axis('off')
fig.colorbar(dsm_plot, ax=axs[1], label='Elevation (m ?)')

plt.tight_layout()
plt.savefig('rgb_dsm_comparison.png')
plt.show()

rgb_image.close()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio\\_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio\\_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio\\_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Track3-Truth/JAX_068_DSM.tif: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[5], line 11
#       8 rgb_image = rasterio.open(rgb_image_path)
#      10 # Open the DSM file
# ---> 11 dsm_dataset = rasterio.open(dsm_path)
#      13 # Print basic information about DSM
#      14 print("DSM File info:")
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python313\Lib\site-packages\rasterio\env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python313\Lib\site-packages\rasterio\__init__.py:368, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     365     path = _parse_path(raw_dataset_path)
#     367 if mode == "r":
# --> 368     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     369 elif mode == "r+":
#     370     dataset = get_writer_for_path(path, driver=driver)(
#     371         path, mode, driver=driver, sharing=sharing, **kwargs
#     372     )
#
# File rasterio\\_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: Track3-Truth/JAX_068_DSM.tif: No such file or directory

# %% [markdown]
# # Vizualizing Lat, Long, Alt, Off-Nadir and Azimuth Distribution of all views of one scene

# %%
def extract_rpc_data(tif_path):
    """Extract RPC data from rgb TIF file"""
    with rasterio.open(tif_path) as src:
        # Get RPC data
        rpc_data = {}
        try:
            # Check if there are RPC tags
            if 'RPC' in src.tag_namespaces():
                rpc_tags = src.tags(ns='RPC')
                
                # Extract all RPC parameters
                rpc_data["LAT_OFF"] = float(rpc_tags.get("LAT_OFF", 0))
                rpc_data["LONG_OFF"] = float(rpc_tags.get("LONG_OFF", 0))
                rpc_data["HEIGHT_OFF"] = float(rpc_tags.get("HEIGHT_OFF", 0))
                rpc_data["LAT_SCALE"] = float(rpc_tags.get("LAT_SCALE", 1))
                rpc_data["LONG_SCALE"] = float(rpc_tags.get("LONG_SCALE", 1))
                rpc_data["HEIGHT_SCALE"] = float(rpc_tags.get("HEIGHT_SCALE", 1))
                rpc_data["LINE_OFF"] = float(rpc_tags.get("LINE_OFF", 0))
                rpc_data["SAMP_OFF"] = float(rpc_tags.get("SAMP_OFF", 0))
                rpc_data["LINE_SCALE"] = float(rpc_tags.get("LINE_SCALE", 1))
                rpc_data["SAMP_SCALE"] = float(rpc_tags.get("SAMP_SCALE", 1))
                
                # Parse coefficient arrays
                for coef in ["LINE_NUM_COEFF", "LINE_DEN_COEFF", "SAMP_NUM_COEFF", "SAMP_DEN_COEFF"]:
                    if coef in rpc_tags:
                        # Parse the coefficients from space-separated string
                        rpc_data[coef] = [float(val) for val in rpc_tags[coef].split()]
        except Exception as e:
            print(f"Error extracting RPC data from {os.path.basename(tif_path)}: {e}")
            return None
        
        return rpc_data

def calculate_viewing_angles(rpc_data):
    """Calculate approximate satellite viewing angles from RPC data"""
    if not rpc_data:
        return None, None
    
    # Extract first-order coefficients for height
    try:
        line_z_coef = rpc_data["LINE_NUM_COEFF"][3]  # Coefficient for Z
        samp_z_coef = rpc_data["SAMP_NUM_COEFF"][3]  # Coefficient for Z
        
        # ToDo Check off_nadir_angle calculation
        # Estimate off-nadir angle
        gradient_magnitude = math.sqrt(line_z_coef**2 + samp_z_coef**2)
        off_nadir_angle = math.atan(gradient_magnitude) * (180/math.pi) * 15
        off_nadir_angle = min(45, max(0, off_nadir_angle))
        
        # ToDo Check azimuth calculation
        # Estimate azimuth angle
        azimuth = math.atan2(samp_z_coef, line_z_coef) * (180/math.pi)
        if azimuth < 0:
            azimuth += 360
            
        return off_nadir_angle, azimuth
    except (KeyError, IndexError) as e:
        print(f"Error calculating viewing angles: {e}")
        return None, None

def process_multiple_images(folder_path, pattern):
    """Process multiple RGB images to extract location and viewing angles"""
    # Find all matching files
    rgb_files = glob.glob(os.path.join(folder_path, pattern))
    
    if not rgb_files:
        print(f"No files matching pattern '{pattern}' found in {folder_path}")
        return
    
    print(f"Found {len(rgb_files)} RGB images")
    
    # Create a table for results
    results = []
    
    for rgb_file in rgb_files:
        file_name = os.path.basename(rgb_file)
        
        # Extract RPC data
        rpc_data = extract_rpc_data(rgb_file)
        
        if rpc_data:
            # Get location
            lat = rpc_data.get("LAT_OFF")
            lon = rpc_data.get("LONG_OFF")
            alt = rpc_data.get("HEIGHT_OFF")
            
            # Calculate viewing angles
            off_nadir, azimuth = calculate_viewing_angles(rpc_data)
            
            # Add to results
            results.append({
                "file_name": file_name,
                "latitude": lat,
                "longitude": lon,
                "altitude": alt,
                "off_nadir_angle": off_nadir,
                "azimuth": azimuth,
                "google_maps_format": f"{lat}, {lon}"
            })
        else:
            print(f"Could not extract RPC data from {file_name}")
    
    # Sort results by filename
    results.sort(key=lambda x: x['file_name'])
    
    # Print results in a table format
    print("\nResults (sorted by filename):")
    print("-" * 100)
    print(f"{'File Name':<20} {'Latitude':<10} {'Longitude':<12} {'Altitude':<10} {'Off-Nadir':<10} {'Azimuth':<10} {'Google Maps Format':<25}")
    print("-" * 100)
    
    for r in results:
        print(f"{r['file_name']:<20} {r['latitude']:<10.6f} {r['longitude']:<12.6f} {r['altitude']:<10.1f} {r['off_nadir_angle']:<10.2f} {r['azimuth']:<10.2f} {r['google_maps_format']:<25}")
    
    return results

# Process all RGB images in the folder
RGB_folder = "Track3-RGB-1"
results = process_multiple_images(RGB_folder, "JAX_068_*.tif")

# Optionally visualize the different viewing angles
if results:
    # Create a visualization of the different viewing angles
    plt.figure(figsize=(12, 10))
    
    # Plot center point
    lat_center = results[0]['latitude']
    lon_center = results[0]['longitude']
    plt.scatter([lon_center], [lat_center], c='black', s=150, marker='o', label='View Center')
    
    # Plot viewing directions
    for r in results:
        # Use azimuth to calculate direction vector
        azimuth_rad = r['azimuth'] * (math.pi/180)
        # Scale vector length by off-nadir angle (more oblique = longer vector)
        vector_length = r['off_nadir_angle'] / 45.0 * 0.01  # Scale factor for visualization
        
        # Calculate endpoint of direction vector
        # Note: azimuth is clockwise from north, so we need to convert to standard angle
        dx = vector_length * math.sin(azimuth_rad)
        dy = vector_length * math.cos(azimuth_rad)
        
        # Plot arrow
        plt.arrow(lon_center, lat_center, dx, dy, 
                  head_width=0.001, head_length=0.002, 
                  fc='blue', ec='blue', 
                  length_includes_head=True)
        
        # Extract the number from the filename (e.g., "001" from JAX_068_001_RGB.tif)
        view_number = os.path.basename(r['file_name']).split('_')[2]
        
        # Add label with bigger size and red color
        plt.text(lon_center + dx*1.1, lat_center + dy*1.1, 
                 view_number, 
                 fontsize=14,  # Increased font size
                 color='black'
                 )  # Made bold for better visibility
    
    plt.title('Satellite Viewing Directions for Different Images', fontsize=16)
    plt.xlabel('Longitude', fontsize=16)
    plt.ylabel('Latitude', fontsize=16)
    plt.grid(True)
    plt.legend(fontsize=12)
    plt.tight_layout()
    plt.savefig('viewing_angles_visualization.png', dpi=300)  # Higher DPI for better quality
    plt.show()
# Out:
# Found 19 RGB images
#
# Results (sorted by filename):
# ----------------------------------------------------------------------------------------------------
# File Name            Latitude   Longitude    Altitude   Off-Nadir  Azimuth    Google Maps Format
# ----------------------------------------------------------------------------------------------------
# JAX_068_001_RGB.tif  30.299200  -81.639700   -21.0      22.09      249.68     30.2992, -81.6397
# JAX_068_002_RGB.tif  30.299400  -81.639700   -21.0      15.29      244.67     30.2994, -81.6397
# JAX_068_003_RGB.tif  30.300700  -81.639600   -19.0      19.98      225.28     30.3007, -81.6396
# JAX_068_004_RGB.tif  30.299600  -81.640300   -20.0      9.12       92.35      30.2996, -81.6403
# JAX_068_005_RGB.tif  30.299800  -81.640800   -19.0      19.06      250.69     30.2998, -81.6408
# JAX_068_006_RGB.tif  30.300300  -81.640800   -21.0      16.66      314.36     30.3003, -81.6408
# JAX_068_007_RGB.tif  30.299900  -81.640200   -21.0      13.79      138.92     30.2999, -81.6402
# JAX_068_009_RGB.tif  30.302700  -81.640100   -19.0      25.03      152.82     30.3027, -81.6401
# JAX_068_010_RGB.tif  30.315100  -81.640000   -19.0      34.25      157.85     30.3151, -81.64
# JAX_068_011_RGB.tif  30.299600  -81.640600   -21.0      5.82       218.05     30.2996, -81.6406
# JAX_068_012_RGB.tif  30.299800  -81.640900   -21.0      18.92      355.96     30.2998, -81.6409
# JAX_068_013_RGB.tif  30.300900  -81.640100   -21.0      21.02      171.95     30.3009, -81.6401
# JAX_068_014_RGB.tif  30.301300  -81.638600   -19.0      23.80      98.81      30.3013, -81.6386
# JAX_068_015_RGB.tif  30.300400  -81.641400   -19.0      26.77      274.04     30.3004, -81.6414
# JAX_068_016_RGB.tif  30.301000  -81.640000   -19.0      21.09      138.69     30.301, -81.64
# JAX_068_018_RGB.tif  30.299400  -81.639800   -21.0      7.32       110.67     30.2994, -81.6398
# JAX_068_019_RGB.tif  30.300000  -81.640900   -21.0      13.57      250.64     30.3, -81.6409
# JAX_068_020_RGB.tif  30.299500  -81.639600   -19.0      26.82      99.85      30.2995, -81.6396
# JAX_068_022_RGB.tif  30.299500  -81.641200   -21.0      13.54      303.90     30.2995, -81.6412

# %%
# Define the scene ID and folder
scene_id = "JAX_068"
RGB_folder = "Track3-RGB-1"

# Path to your lat_lon PNG
lat_lon_png = f"lat_lon.png"

# Find all RGB images for this scene
pattern = f"{scene_id}_*_RGB.tif"
rgb_files = glob.glob(os.path.join(RGB_folder, pattern))
rgb_files.sort()

print(f"Found {len(rgb_files)} RGB images for scene {scene_id}")

# Extract metadata and calculate diversity
image_data = []

for rgb_file in rgb_files:
    file_name = os.path.basename(rgb_file)
    view_number = file_name.split('_')[2]
    
    with rasterio.open(rgb_file) as src:
        if 'RPC' in src.tag_namespaces():
            rpc_tags = src.tags(ns='RPC')
            
            # Get location data
            lat = float(rpc_tags.get("LAT_OFF", 0))
            lon = float(rpc_tags.get("LONG_OFF", 0))
            alt = float(rpc_tags.get("HEIGHT_OFF", 0))
            
            # Calculate viewing angles
            try:
                line_z_coef = float(rpc_tags.get("LINE_NUM_COEFF", "0 0 0 0").split()[3])
                samp_z_coef = float(rpc_tags.get("SAMP_NUM_COEFF", "0 0 0 0").split()[3])
                
                gradient = np.sqrt(line_z_coef**2 + samp_z_coef**2)
                off_nadir = min(45, np.arctan(gradient) * (180/np.pi) * 15)
                
                azimuth = np.arctan2(samp_z_coef, line_z_coef) * (180/np.pi)
                if azimuth < 0:
                    azimuth += 360
                
                # Store the data
                image_data.append({
                    'file': rgb_file,
                    'name': file_name,
                    'view': view_number,
                    'features': [lat, lon, alt, off_nadir, azimuth],
                    'lat': lat,
                    'lon': lon,
                    'alt': alt,
                    'off_nadir': off_nadir,
                    'azimuth': azimuth
                })
            except Exception as e:
                print(f"Could not process {file_name}: {e}")

# We need at least 4 images
if len(image_data) < 4:
    print(f"Not enough images found (only {len(image_data)})")
    exit()

# Normalize the features for distance calculation
features = np.array([img['features'] for img in image_data])
features_min = features.min(axis=0)
features_max = features.max(axis=0)
features_range = features_max - features_min
# Avoid division by zero
features_range[features_range == 0] = 1
features_norm = (features - features_min) / features_range

# Select 4 diverse images using a greedy approach
selected_indices = []
remaining_indices = list(range(len(image_data)))

# Start with the image that has the most extreme feature (farthest from the mean)
mean_features = np.mean(features_norm, axis=0)
distances_from_mean = [distance.euclidean(features_norm[i], mean_features) for i in range(len(features_norm))]
first_idx = np.argmax(distances_from_mean)
selected_indices.append(first_idx)
remaining_indices.remove(first_idx)

# Select remaining 3 images that maximize diversity
while len(selected_indices) < 4 and remaining_indices:
    max_min_dist = -1
    next_idx = -1
    
    for i in remaining_indices:
        # Find minimum distance to any already selected image
        min_dist = min([distance.euclidean(features_norm[i], features_norm[j]) for j in selected_indices])
        
        if min_dist > max_min_dist:
            max_min_dist = min_dist
            next_idx = i
    
    if next_idx != -1:
        selected_indices.append(next_idx)
        remaining_indices.remove(next_idx)
    else:
        break

# Create a figure with 5 subplots - one for lat_lon PNG and four for the diverse images
fig = plt.figure(figsize=(15, 18))

# Create a grid for all subplots (3x2)
axes = [plt.subplot2grid((3, 2), (0, 0)),  # First row, first column
        plt.subplot2grid((3, 2), (0, 1)),  # First row, second column
        plt.subplot2grid((3, 2), (1, 0)),  # Second row, first column
        plt.subplot2grid((3, 2), (1, 1)),  # Second row, second column
        plt.subplot2grid((3, 2), (2, 0), colspan=2)]  # Third row, spans both columns

# Add lat_lon PNG to the centered bottom position
lat_lon_img = plt.imread(lat_lon_png)
axes[4].imshow(lat_lon_img)
axes[4].axis('off')

# Display the 4 selected images in the top two rows
for i, idx in enumerate(selected_indices):
    img_data = image_data[idx]
    
    # Read the RGB image
    with rasterio.open(img_data['file']) as src:
        red = src.read(1)
        green = src.read(2)
        blue = src.read(3)
        
        rgb_display = np.stack((red, green, blue), axis=2)
        rgb_display = np.clip(rgb_display, 0, 255).astype(np.uint8)
        
        # Display the image
        axes[i].imshow(rgb_display)
        axes[i].set_title(f"View {img_data['view']}", fontsize=16, color='red', fontweight='bold')
        axes[i].axis('off')
        
        # Add metadata as text overlay
        info_text = (
            f"Lat: {img_data['lat']:.4f}°\n"
            f"Lon: {img_data['lon']:.4f}°\n"
            f"Alt: {img_data['alt']:.1f}m\n"
            f"Off-nadir: {img_data['off_nadir']:.1f}°\n"
            f"Azimuth: {img_data['azimuth']:.1f}°"
        )
        
        # Add white text with black outline for better visibility
        axes[i].text(10, 60, info_text, 
                   fontsize=14, color='white', fontweight='bold',
                   bbox=dict(facecolor='black', alpha=0.7))

plt.suptitle(f'Four Most Diverse Views for Scene {scene_id}', fontsize=18)
plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.savefig(f'{scene_id}_diverse_views_with_latlon.png', dpi=300)
plt.show()

# Print information about the selected images
print("\nSelected Images:")
print("-" * 80)
print(f"{'View':<6} {'Latitude':<10} {'Longitude':<12} {'Altitude':<10} {'Off-Nadir':<10} {'Azimuth':<10}")
print("-" * 80)

for idx in selected_indices:
    img = image_data[idx]
    print(f"{img['view']:<6} {img['lat']:<10.4f} {img['lon']:<12.4f} {img['alt']:<10.1f} {img['off_nadir']:<10.1f} {img['azimuth']:<10.1f}")
# Out:
# Found 19 RGB images for scene JAX_068
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 113
#     106 axes = [plt.subplot2grid((3, 2), (0, 0)),  # First row, first column
#     107         plt.subplot2grid((3, 2), (0, 1)),  # First row, second column
#     108         plt.subplot2grid((3, 2), (1, 0)),  # Second row, first column
#     109         plt.subplot2grid((3, 2), (1, 1)),  # Second row, second column
#     110         plt.subplot2grid((3, 2), (2, 0), colspan=2)]  # Third row, spans both columns
#     112 # Add lat_lon PNG to the centered bottom position
# --> 113 lat_lon_img = plt.imread(lat_lon_png)
#     114 axes[4].imshow(lat_lon_img)
#     115 axes[4].axis('off')
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:2607, in imread(fname, format)
#    2603 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2604 def imread(
#    2605         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2606 ) -> np.ndarray:
# -> 2607     return matplotlib.image.imread(fname, format)
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\image.py:1512, in imread(fname, format)
#    1505 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1506     # Pillow doesn't handle URLs directly.
#    1507     raise ValueError(
#    1508         "Please open the URL for reading and pass the "
#    1509         "result to Pillow, e.g. with "
#    1510         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1511         )
# -> 1512 with img_open(fname) as image:
#    1513     return (_pil_png_to_float_array(image)
#    1514             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1515             pil_to_array(image))
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\ImageFile.py:135, in ImageFile.__init__(self, fp, filename)
#     131 self.decodermaxblock = MAXBLOCK
#     133 if is_path(fp):
#     134     # filename
# --> 135     self.fp = open(fp, "rb")
#     136     self.filename = os.fspath(fp)
#     137     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lat_lon.png'

# %%
import os
import glob
import math
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import rasterio

def extract_rpc_data(tif_path):
    """Extract RPC data from rgb TIF file"""
    with rasterio.open(tif_path) as src:
        # Get RPC data
        rpc_data = {}
        try:
            # Check if there are RPC tags
            if 'RPC' in src.tag_namespaces():
                rpc_tags = src.tags(ns='RPC')
                
                # Extract all RPC parameters
                rpc_data["LAT_OFF"] = float(rpc_tags.get("LAT_OFF", 0))
                rpc_data["LONG_OFF"] = float(rpc_tags.get("LONG_OFF", 0))
                rpc_data["HEIGHT_OFF"] = float(rpc_tags.get("HEIGHT_OFF", 0))
                rpc_data["LAT_SCALE"] = float(rpc_tags.get("LAT_SCALE", 1))
                rpc_data["LONG_SCALE"] = float(rpc_tags.get("LONG_SCALE", 1))
                rpc_data["HEIGHT_SCALE"] = float(rpc_tags.get("HEIGHT_SCALE", 1))
                rpc_data["LINE_OFF"] = float(rpc_tags.get("LINE_OFF", 0))
                rpc_data["SAMP_OFF"] = float(rpc_tags.get("SAMP_OFF", 0))
                rpc_data["LINE_SCALE"] = float(rpc_tags.get("LINE_SCALE", 1))
                rpc_data["SAMP_SCALE"] = float(rpc_tags.get("SAMP_SCALE", 1))
                
                # Parse coefficient arrays
                for coef in ["LINE_NUM_COEFF", "LINE_DEN_COEFF", "SAMP_NUM_COEFF", "SAMP_DEN_COEFF"]:
                    if coef in rpc_tags:
                        # Parse the coefficients from space-separated string
                        rpc_data[coef] = [float(val) for val in rpc_tags[coef].split()]
        except Exception as e:
            print(f"Error extracting RPC data from {os.path.basename(tif_path)}: {e}")
            return None
        
        return rpc_data

def calculate_viewing_angles(rpc_data):
    """Calculate approximate satellite viewing angles from RPC data"""
    if not rpc_data:
        return None, None
    
    # Extract first-order coefficients for height
    try:
        line_z_coef = rpc_data["LINE_NUM_COEFF"][3]  # Coefficient for Z
        samp_z_coef = rpc_data["SAMP_NUM_COEFF"][3]  # Coefficient for Z
        
        # Estimate off-nadir angle
        gradient_magnitude = math.sqrt(line_z_coef**2 + samp_z_coef**2)
        off_nadir_angle = math.atan(gradient_magnitude) * (180/math.pi) * 15
        off_nadir_angle = min(45, max(0, off_nadir_angle))
        
        # Estimate azimuth angle
        azimuth = math.atan2(samp_z_coef, line_z_coef) * (180/math.pi)
        if azimuth < 0:
            azimuth += 360
            
        return off_nadir_angle, azimuth
    except (KeyError, IndexError) as e:
        print(f"Error calculating viewing angles: {e}")
        return None, None

def estimate_camera_position(lat, lon, alt, off_nadir, azimuth, satellite_height=500000):
    """
    Estimate the camera position in 3D space
    
    Args:
        lat, lon, alt: The ground point location (degrees, degrees, meters)
        off_nadir: Off-nadir angle in degrees
        azimuth: Azimuth angle in degrees
        satellite_height: Approximate satellite height in meters
    
    Returns:
        tuple: (camera_x, camera_y, camera_z) in meters in local ENU coordinates
    """
    # Convert ground point to a local East-North-Up (ENU) coordinate system
    # For simplicity, we'll use (0,0,0) as our local origin
    
    # Calculate slant range (distance from ground to satellite)
    # assuming a typical satellite height
    slant_range = satellite_height / math.cos(math.radians(off_nadir))
    
    # Convert azimuth and off-nadir to 3D vector
    # Azimuth is measured clockwise from North
    # Off-nadir is measured from the vertical
    
    # Calculate direction vector components
    # X is East, Y is North, Z is Up
    x = slant_range * math.sin(math.radians(off_nadir)) * math.sin(math.radians(azimuth))
    y = slant_range * math.sin(math.radians(off_nadir)) * math.cos(math.radians(azimuth))
    z = slant_range * math.cos(math.radians(off_nadir))
    
    return (x, y, z)

def latlon_to_xyz(lat, lon, alt=0, ref_lat=None, ref_lon=None):
    """
    Convert latitude, longitude to local ENU coordinates using a simpler approach
    
    Args:
        lat, lon: Point coordinates (degrees)
        alt: Altitude in meters
        ref_lat, ref_lon: Reference point (degrees), if None will use the input point
    
    Returns:
        tuple: (x, y, z) in meters in local ENU coordinates
    """
    # If no reference point specified, use the input point
    if ref_lat is None:
        ref_lat = lat
    if ref_lon is None:
        ref_lon = lon
    
    # Earth radius in meters
    R = 6378137.0
    
    # Convert to radians
    lat_rad = math.radians(lat)
    lon_rad = math.radians(lon)
    ref_lat_rad = math.radians(ref_lat)
    ref_lon_rad = math.radians(ref_lon)
    
    # Calculate distance in east direction (x)
    x = R * math.cos(ref_lat_rad) * (lon_rad - ref_lon_rad)
    
    # Calculate distance in north direction (y)
    y = R * (lat_rad - ref_lat_rad)
    
    # Z is just the altitude (relative to reference altitude)
    z = alt
    
    return (x, y, z)

def process_multiple_images(folder_path, pattern):
    """Process multiple RGB images to extract location, viewing angles, and camera positions"""
    # Find all matching files
    rgb_files = glob.glob(os.path.join(folder_path, pattern))
    
    if not rgb_files:
        print(f"No files matching pattern '{pattern}' found in {folder_path}")
        return
    
    print(f"Found {len(rgb_files)} RGB images")
    
    # Create a table for results
    results = []
    
    # Process each image
    for rgb_file in rgb_files:
        file_name = os.path.basename(rgb_file)
        
        # Extract RPC data
        rpc_data = extract_rpc_data(rgb_file)
        
        if rpc_data:
            # Get location
            lat = rpc_data.get("LAT_OFF")
            lon = rpc_data.get("LONG_OFF")
            alt = rpc_data.get("HEIGHT_OFF")
            
            # Calculate viewing angles
            off_nadir, azimuth = calculate_viewing_angles(rpc_data)
            
            # Add to results
            results.append({
                "file_name": file_name,
                "latitude": lat,
                "longitude": lon,
                "altitude": alt,
                "off_nadir_angle": off_nadir,
                "azimuth": azimuth,
                "google_maps_format": f"{lat}, {lon}"
            })
        else:
            print(f"Could not extract RPC data from {file_name}")
    
    # Sort results by filename
    results.sort(key=lambda x: x['file_name'])
    
    # Calculate reference point (first image)
    ref_lat = results[0]['latitude']
    ref_lon = results[0]['longitude']
    ref_alt = results[0]['altitude']
    
    # Add camera positions
    for r in results:
        # Estimate camera position in the sky relative to the ground point
        cam_x, cam_y, cam_z = estimate_camera_position(
            r['latitude'], r['longitude'], r['altitude'],
            r['off_nadir_angle'], r['azimuth']
        )
        
        # Convert ground point to local coordinates
        ground_x, ground_y, ground_z = latlon_to_xyz(
            r['latitude'], r['longitude'], r['altitude'],
            ref_lat, ref_lon
        )
        
        # Store camera position in local coordinates relative to the reference point
        r['camera_x'] = cam_x
        r['camera_y'] = cam_y
        r['camera_z'] = cam_z
        
        # Store ground point in local coordinates
        r['ground_x'] = ground_x
        r['ground_y'] = ground_y
        r['ground_z'] = ground_z
    
    # Print results in a table format
    print("\nResults (sorted by filename):")
    print("-" * 100)
    print(f"{'File Name':<20} {'Latitude':<10} {'Longitude':<12} {'Off-Nadir':<10} {'Azimuth':<10} {'Camera X':<10} {'Camera Y':<10} {'Camera Z':<10}")
    print("-" * 100)
    
    for r in results:
        print(f"{r['file_name']:<20} {r['latitude']:<10.6f} {r['longitude']:<12.6f} {r['off_nadir_angle']:<10.2f} {r['azimuth']:<10.2f} {r['camera_x']:<10.2f} {r['camera_y']:<10.2f} {r['camera_z']:<10.2f}")
    
    return results, ref_lat, ref_lon, ref_alt

def visualize_camera_positions_multi_angle(results, ref_lat, ref_lon, ref_alt):
    """Create multiple visualizations of camera positions from different angles"""
    # Create figures for different angles
    
    # 1. Top view (looking down at XY plane)
    plt.figure(figsize=(12, 10))
    
    # Extract camera positions
    camera_x = [r['camera_x'] for r in results]
    camera_y = [r['camera_y'] for r in results]
    camera_z = [r['camera_z'] for r in results]
    
    # Extract ground points
    ground_x = [r['ground_x'] for r in results]
    ground_y = [r['ground_y'] for r in results]
    ground_z = [r['ground_z'] for r in results]
    
    # Plot reference ground point
    plt.scatter([0], [0], c='red', s=200, marker='o', label='Reference Ground Point')
    
    # Plot camera positions (top-down view)
    plt.scatter(camera_x, camera_y, c='blue', s=100, marker='^', label='Camera Positions')
    
    # Plot lines connecting cameras to ground points (top-down view)
    for i in range(len(results)):
        plt.plot([ground_x[i], camera_x[i]], [ground_y[i], camera_y[i]], 'k--', alpha=0.3)
        
        # Add image ID labels
        view_number = os.path.basename(results[i]['file_name']).split('_')[2]
        plt.text(camera_x[i], camera_y[i], view_number, fontsize=12)
    
    # Set labels and title
    plt.xlabel('East (m)', fontsize=14)
    plt.ylabel('North (m)', fontsize=14)
    plt.title('Top-down View of Camera Positions', fontsize=16)
    plt.grid(True)
    plt.legend(fontsize=12)
    plt.axis('equal')
    plt.tight_layout()
    plt.savefig('camera_positions_topdown.png', dpi=300)
    plt.show()
    
    # 2. 3D view - angle 1 (default)
    fig = plt.figure(figsize=(12, 10))
    ax = fig.add_subplot(111, projection='3d')
    
    # Plot reference ground point
    ax.scatter([0], [0], [0], c='red', s=200, marker='o', label='Reference Ground Point')
    
    # Plot camera positions
    ax.scatter(camera_x, camera_y, camera_z, c='blue', s=100, marker='^', label='Camera Positions')
    
    # Plot lines connecting cameras to ground points
    for i in range(len(results)):
        ax.plot([ground_x[i], camera_x[i]], [ground_y[i], camera_y[i]], [ground_z[i], camera_z[i]], 'k--', alpha=0.3)
        
        # Add image ID labels
        view_number = os.path.basename(results[i]['file_name']).split('_')[2]
        ax.text(camera_x[i], camera_y[i], camera_z[i], view_number, fontsize=12)
    
    # Set labels and title
    ax.set_xlabel('East (m)', fontsize=14)
    ax.set_ylabel('North (m)', fontsize=14)
    ax.set_zlabel('Up (m)', fontsize=14)
    ax.set_title('3D Camera Positions - View Angle 1', fontsize=16)
    
    # Set equal aspect ratio
    max_range = np.array([
        max(camera_x) - min(camera_x),
        max(camera_y) - min(camera_y),
        max(camera_z) - min(camera_z)
    ]).max() / 2.0
    
    mid_x = (max(camera_x) + min(camera_x)) / 2
    mid_y = (max(camera_y) + min(camera_y)) / 2
    mid_z = (max(camera_z) + min(camera_z)) / 2
    
    ax.set_xlim(mid_x - max_range, mid_x + max_range)
    ax.set_ylim(mid_y - max_range, mid_y + max_range)
    ax.set_zlim(mid_z - max_range, mid_z + max_range)
    
    # Set specific view angle 1
    ax.view_init(elev=30, azim=45)
    
    # Add legend
    ax.legend(fontsize=12)
    
    plt.tight_layout()
    plt.savefig('camera_positions_3d_angle1.png', dpi=300)
    plt.show()
    
    # 3. 3D view - angle 2 (side view)
    fig = plt.figure(figsize=(12, 10))
    ax = fig.add_subplot(111, projection='3d')
    
    # Plot reference ground point
    ax.scatter([0], [0], [0], c='red', s=200, marker='o', label='Reference Ground Point')
    
    # Plot camera positions
    ax.scatter(camera_x, camera_y, camera_z, c='blue', s=100, marker='^', label='Camera Positions')
    
    # Plot lines connecting cameras to ground points
    for i in range(len(results)):
        ax.plot([ground_x[i], camera_x[i]], [ground_y[i], camera_y[i]], [ground_z[i], camera_z[i]], 'k--', alpha=0.3)
        
        # Add image ID labels
        view_number = os.path.basename(results[i]['file_name']).split('_')[2]
        ax.text(camera_x[i], camera_y[i], camera_z[i], view_number, fontsize=12)
    
    # Set labels and title
    ax.set_xlabel('East (m)', fontsize=14)
    ax.set_ylabel('North (m)', fontsize=14)
    ax.set_zlabel('Up (m)', fontsize=14)
    ax.set_title('3D Camera Positions - View Angle 2 (Side View)', fontsize=16)
    
    # Set equal aspect ratio
    ax.set_xlim(mid_x - max_range, mid_x + max_range)
    ax.set_ylim(mid_y - max_range, mid_y + max_range)
    ax.set_zlim(mid_z - max_range, mid_z + max_range)
    
    # Set specific view angle 2 (side view)
    ax.view_init(elev=0, azim=90)
    
    # Add legend
    ax.legend(fontsize=12)
    
    plt.tight_layout()
    plt.savefig('camera_positions_3d_angle2.png', dpi=300)
    plt.show()
    
    # 4. 3D view - angle 3 (front view)
    fig = plt.figure(figsize=(12, 10))
    ax = fig.add_subplot(111, projection='3d')
    
    # Plot reference ground point
    ax.scatter([0], [0], [0], c='red', s=200, marker='o', label='Reference Ground Point')
    
    # Plot camera positions
    ax.scatter(camera_x, camera_y, camera_z, c='blue', s=100, marker='^', label='Camera Positions')
    
    # Plot lines connecting cameras to ground points
    for i in range(len(results)):
        ax.plot([ground_x[i], camera_x[i]], [ground_y[i], camera_y[i]], [ground_z[i], camera_z[i]], 'k--', alpha=0.3)
        
        # Add image ID labels
        view_number = os.path.basename(results[i]['file_name']).split('_')[2]
        ax.text(camera_x[i], camera_y[i], camera_z[i], view_number, fontsize=12)
    
    # Set labels and title
    ax.set_xlabel('East (m)', fontsize=14)
    ax.set_ylabel('North (m)', fontsize=14)
    ax.set_zlabel('Up (m)', fontsize=14)
    ax.set_title('3D Camera Positions - View Angle 3 (Front View)', fontsize=16)
    
    # Set equal aspect ratio
    ax.set_xlim(mid_x - max_range, mid_x + max_range)
    ax.set_ylim(mid_y - max_range, mid_y + max_range)
    ax.set_zlim(mid_z - max_range, mid_z + max_range)
    
    # Set specific view angle 3 (front view)
    ax.view_init(elev=20, azim=0)
    
    # Add legend
    ax.legend(fontsize=12)
    
    plt.tight_layout()
    plt.savefig('camera_positions_3d_angle3.png', dpi=300)
    plt.show()
    
    return fig

# Main execution
if __name__ == "__main__":
    # Process all RGB images in the folder
    RGB_folder = "Track3-RGB-1"
    results, ref_lat, ref_lon, ref_alt = process_multiple_images(RGB_folder, "JAX_068_*.tif")
    
    # Visualize camera positions from multiple angles
    if results:
        visualize_camera_positions_multi_angle(results, ref_lat, ref_lon, ref_alt)
        
        # Export camera positions to a text file (useful for 3D reconstruction software)
        with open('camera_positions.txt', 'w') as f:
            f.write("# Camera positions for 3D reconstruction\n")
            f.write("# Format: image_id,x,y,z,off_nadir,azimuth\n")
            
            for r in results:
                view_number = os.path.basename(r['file_name']).split('_')[2]
                f.write(f"{view_number},{r['camera_x']:.2f},{r['camera_y']:.2f},{r['camera_z']:.2f},{r['off_nadir_angle']:.2f},{r['azimuth']:.2f}\n")
        
        print("\nCamera positions exported to camera_positions.txt")
# Out:
# Found 19 RGB images
#
# Results (sorted by filename):
# ----------------------------------------------------------------------------------------------------
# File Name            Latitude   Longitude    Off-Nadir  Azimuth    Camera X   Camera Y   Camera Z
# ----------------------------------------------------------------------------------------------------
# JAX_068_001_RGB.tif  30.299200  -81.639700   22.09      249.68     -190340.84 -70500.72  500000.00
# JAX_068_002_RGB.tif  30.299400  -81.639700   15.29      244.67     -123537.92 -58478.86  500000.00
# JAX_068_003_RGB.tif  30.300700  -81.639600   19.98      225.28     -129184.41 -127916.38 500000.00
# JAX_068_004_RGB.tif  30.299600  -81.640300   9.12       92.35      80188.27   -3291.30   500000.00
# JAX_068_005_RGB.tif  30.299800  -81.640800   19.06      250.69     -163060.28 -57149.45  500000.00
# JAX_068_006_RGB.tif  30.300300  -81.640800   16.66      314.36     -106961.41 104606.19  500000.00
# JAX_068_007_RGB.tif  30.299900  -81.640200   13.79      138.92     80628.31   -92478.16  500000.00
# JAX_068_009_RGB.tif  30.302700  -81.640100   25.03      152.82     106659.13  -207724.89 500000.00
# JAX_068_010_RGB.tif  30.315100  -81.640000   34.25      157.85     128340.47  -315262.74 500000.00
# JAX_068_011_RGB.tif  30.299600  -81.640600   5.82       218.05     -31393.50  -40102.90  500000.00
# JAX_068_012_RGB.tif  30.299800  -81.640900   18.92      355.96     -12073.45  170950.75  500000.00
# JAX_068_013_RGB.tif  30.300900  -81.640100   21.02      171.95     26907.06   -190194.54 500000.00
# JAX_068_014_RGB.tif  30.301300  -81.638600   23.80      98.81      217945.81  -33782.07  500000.00
# JAX_068_015_RGB.tif  30.300400  -81.641400   26.77      274.04     -251601.65 17751.88   500000.00
# JAX_068_016_RGB.tif  30.301000  -81.640000   21.09      138.69     127273.41  -144829.09 500000.00
# JAX_068_018_RGB.tif  30.299400  -81.639800   7.32       110.67     60121.84   -22677.26  500000.00
# JAX_068_019_RGB.tif  30.300000  -81.640900   13.57      250.64     -113829.09 -39986.70  500000.00
# JAX_068_020_RGB.tif  30.299500  -81.639600   26.82      99.85      249011.65  -43213.80  500000.00
# JAX_068_022_RGB.tif  30.299500  -81.641200   13.54      303.90     -99931.77  67145.74   500000.00
# Camera positions exported to camera_positions.txt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from itertools import combinations

def d_optimal_greedy(camera_positions, focus_point, k):
    rel = camera_positions - focus_point
    u = -rel / np.linalg.norm(rel, axis=1, keepdims=True)
    selected = []
    for _ in range(k):
        best_j, best_det = None, -np.inf
        for j in range(u.shape[0]):
            if j in selected: continue
            F = u[selected + [j]].T @ u[selected + [j]]
            detF = np.linalg.det(F)
            if detF > best_det:
                best_det, best_j = detF, j
        selected.append(best_j)
    return selected

def least_spread_bruteforce(camera_positions, focus_point, k):
    rel = camera_positions - focus_point
    u = -rel / np.linalg.norm(rel, axis=1, keepdims=True)
    worst_det = np.inf
    worst_inds = None
    for inds in combinations(range(u.shape[0]), k):
        F = u[list(inds)].T @ u[list(inds)]
        detF = np.linalg.det(F)
        if detF < worst_det:
            worst_det, worst_inds = detF, inds
    return list(worst_inds)

# === Load data ===
df = pd.read_csv(
    "camera_positions.txt",
    comment='#',
    header=None,
    names=['image_id', 'x', 'y', 'z', 'off_nadir', 'azimuth']
)
positions = df[['x', 'y', 'z']].values
focus = np.array([0.0, 0.0, 0.0])
k = 5

# === Compute selections ===
opt_inds = d_optimal_greedy(positions, focus, k)
bad_inds = least_spread_bruteforce(positions, focus, k)

# === Print out their IDs ===
best_ids = df.loc[opt_inds, 'image_id'].tolist()
worst_ids = df.loc[bad_inds, 'image_id'].tolist()
print("Best-spread camera IDs:", best_ids)
print("Worst-spread camera IDs:", worst_ids)

# === Masks for plotting ===
mask_opt = np.zeros(len(df), bool); mask_opt[opt_inds] = True
mask_bad = np.zeros(len(df), bool); mask_bad[bad_inds] = True

# === Plot 1: Best Spread (D-optimal) ===
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(
    positions[~mask_opt,0],
    positions[~mask_opt,1],
    positions[~mask_opt,2],
    c='blue', marker='o', alpha=0.4, label='Other cameras'
)
ax.scatter(
    positions[mask_opt,0],
    positions[mask_opt,1],
    positions[mask_opt,2],
    c='red', marker='^', s=100, label='D-optimal'
)
ax.scatter(0,0,0, c='black', marker='*', s=200, label='Focus')
ax.set_xlabel('X'); ax.set_ylabel('Y'); ax.set_zlabel('Z')
ax.set_title(f'Best Spread (D-optimal), k={k}')
ax.legend()
plt.tight_layout()

# === Plot 2: Worst Spread (Least-spread) ===
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(
    positions[~mask_bad,0],
    positions[~mask_bad,1],
    positions[~mask_bad,2],
    c='blue', marker='o', alpha=0.4, label='Other cameras'
)
ax.scatter(
    positions[mask_bad,0],
    positions[mask_bad,1],
    positions[mask_bad,2],
    c='green', marker='s', s=100, label='Least-spread'
)
ax.scatter(0,0,0, c='black', marker='*', s=200, label='Focus')
ax.set_xlabel('X'); ax.set_ylabel('Y'); ax.set_zlabel('Z')
ax.set_title(f'Worst Spread (Least-spread), k={k}')
ax.legend()
plt.tight_layout()

plt.show()
# Out:
# Best-spread camera IDs: [2, 20, 10, 12, 15]
# Worst-spread camera IDs: [1, 2, 5, 11, 18]
